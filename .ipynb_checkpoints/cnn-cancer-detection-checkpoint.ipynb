# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import keras 
import tensorflow as tf
import seaborn as sns
import warnings
import os
from PIL import Image

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
physical_devices = tf.config.list_physical_devices()
print("Physical devices:")
for device in physical_devices:
    print(device)
# Out:
# Physical devices:
# PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')

# %%
# !echo "Number of images in test: " $(ls train/ | wc -l)

# !echo "Number of images in test: " $(ls test/ | wc -l)
# Out:
# Number of images in test:  220025
# Number of images in test:  57458

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Competition
#
# (description from Kaggle competition)
#
# In this competition, you must create an algorithm to identify metastatic cancer in small image patches taken from larger digital pathology scans. The data for this competition is a slightly modified version of the PatchCamelyon (PCam) benchmark dataset (the original PCam dataset contains duplicate images due to its probabilistic sampling, however, the version presented on Kaggle does not contain duplicates).
#
# PCam is highly interesting for both its size, simplicity to get started on, and approachability. In the authors' words:
#
#  [PCam] packs the clinically-relevant task of metastasis detection into a straight-forward binary image classification task, akin to CIFAR-10 and MNIST. Models can easily be trained on a single GPU in a couple hours, and achieve competitive scores in the Camelyon16 tasks of tumor detection and whole-slide image diagnosis. Furthermore, the balance between task-difficulty and tractability makes it a prime suspect for fundamental machine learning research on topics as active learning, model uncertainty, and explainability.
#
# ### Data Description
#
#  In this dataset, you are provided with a large number of small pathology images to classify. Files are named with an image id. The train_labels.csv file provides the ground truth for the images in the train folder. You are predicting the labels for the images in the test folder. A positive label indicates that the center 32x32px region of a patch contains at least one pixel of tumor tissue. Tumor tissue in the outer region of the patch does not influence the label. This outer region is provided to enable fully-convolutional models that do not use zero-padding, to ensure consistent behavior when applied to a whole-slide image.
#
# The original PCam dataset contains duplicate images due to its probabilistic sampling, however, the version presented on Kaggle does not contain duplicates. We have otherwise maintained the same data and splits as the PCam benchmark.
#
# ![image.png](attachment:a16e0566-a5b6-4889-bec0-5fee70c289a9.png)

# %%
train_labels_df = pd.read_csv("train_labels.csv")
train_labels_df["label"] = ["Benign" if l == 0 else "Malignant" for l in train_labels_df["label"]]
train_labels_df["file"] = train_labels_df["id"] + ".tif"


train_labels_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220025 entries, 0 to 220024
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      220025 non-null  object
#  1   label   220025 non-null  object
#  2   file    220025 non-null  object
# dtypes: object(3)
# memory usage: 5.0+ MB

# %%
sns.countplot(x=
    train_labels_df["label"], 
              palette="Set2")

total = len(train_labels_df["label"])
for p in plt.gca().patches:
    height = p.get_height()
    plt.text(p.get_x() + p.get_width() / 2., height + 0.1, '{:.1f}%'.format((height / total) * 100),
             ha="center")

plt.xlabel('Target Variable')
plt.ylabel('Counts')
plt.title('Distribution of Binary Target Variable')
plt.show()

# %%
def display_images_in_grid(df, n):
    image_dir = "train/"

    # Create a grid of subplots
    
    num_rows = (n + 3) // 4  # Calculate number of rows needed
    fig, axes = plt.subplots(num_rows, 4, figsize=(12, 3 * num_rows))

    # Loop through the first n rows of the DataFrame
    for i, ax in enumerate(axes.flat):
        if i < n:
            # Construct the full path to the image file
            image_path = os.path.join(image_dir, df.iloc[i]['id'] + '.tif')

            # Load and display the image using PIL
            image = Image.open(image_path)
            image = image.resize((100, 100))
            ax.imshow(image, cmap='gray')
            ax.set_title(df.iloc[i]['label'])
            ax.axis('off')
        else:
            # Remove any extra subplot
            fig.delaxes(ax)

    # Adjust layout
    plt.tight_layout()

    # Show the plot
    plt.show()
    
    
display_images_in_grid(train_labels_df, 24)

# %% [markdown]
# ### Data Splits

# %%
from sklearn.model_selection import train_test_split


DEVTEST_FRAC = 0.1


train_df, dev_test_df = train_test_split(train_labels_df, test_size=DEVTEST_FRAC, random_state=42)
dev_df, test_df = train_test_split(dev_test_df, test_size=0.5, random_state=42)



print("Train: ", len(train_df))
print("Dev: ", len(dev_df))
print("Test: ", len(test_df))
# Out:
# Train:  198022
# Dev:  11001
# Test:  11002

# %% [markdown]
# ### Data Generator with Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

TRAIN_DIR = "train/"


def create_data_generators(train_dir, train_df, dev_df, test_df, target_size=(224, 224), batch_size=32):
    train_datagen = ImageDataGenerator(
        rescale=1.0/255.0,
        shear_range=0.15,
        zoom_range=0.15,
        rotation_range=20,  
        width_shift_range=0.1,  
        height_shift_range=0.1,
        fill_mode='nearest' 
    )

    dev_datagen = ImageDataGenerator(rescale=1.0/255.0)
    test_datagen = ImageDataGenerator(rescale=1.0/255.0)

    train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory=train_dir,
        x_col='file',
        y_col='label',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='binary'
    )

    dev_generator = dev_datagen.flow_from_dataframe(
        dataframe=dev_df,
        directory=train_dir,
        x_col='file',
        y_col='label',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='binary'
    )

    test_generator = test_datagen.flow_from_dataframe(
        dataframe=test_df,
        directory=train_dir,
        x_col='file',
        y_col='label',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='binary'
    )

    return train_generator, dev_generator, test_generator




#build 3 data generators

train_generator, dev_generator, test_generator = create_data_generators(TRAIN_DIR,
                                                                        train_df,
                                                                        dev_df,
                                                                        test_df,
                                                                        target_size=(224, 224),
                                                                        batch_size=128,
                                                                        )
# Out:
# Found 198022 validated image filenames belonging to 2 classes.
# Found 11001 validated image filenames belonging to 2 classes.
# Found 11002 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Establishing baseline: shallow ConvNet

# %%
baseline_cnn_model = keras.Sequential(
    [
        keras.layers.Input((224, 224, 3)),
        
        keras.layers.Conv2D(32, (3, 3), activation="relu"),
        keras.layers.Conv2D(48, (3, 3), strides=(2, 2), activation="relu"),
        keras.layers.Dropout(0.5),
        
        keras.layers.Conv2D(64, (3, 3), strides=(2, 2), activation="relu"),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Dropout(0.5),
        
        keras.layers.Conv2D(128, (3, 3), strides=(2, 2), activation="relu"),
        keras.layers.Dropout(0.5),
        
        keras.layers.Conv2D(256, (3, 3), activation="relu"),
        keras.layers.MaxPooling2D((2, 2)),

        keras.layers.GlobalAveragePooling2D(),
        keras.layers.Flatten(),
        
        keras.layers.Dense(1, activation="sigmoid")
    ], name="baseline_cnn")


baseline_cnn_model.summary()
# Out:
# Model: "baseline_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_54 (Conv2D)              │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_55 (Conv2D)              │ (None, 110, 110, 48)   │        13,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_44 (Dropout)            │ (None, 110, 110, 48)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_56 (Conv2D)              │ (None, 54, 54, 64)     │        27,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_27 (MaxPooling2D) │ (None, 27, 27, 64)     │             0 │
# ...

# %%
baseline_cnn_model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
                           loss="binary_crossentropy",
                           metrics=["accuracy", keras.metrics.AUC()])

# %%
baseline_train_history = baseline_cnn_model.fit(train_generator,
                       validation_data=dev_generator,
                       batch_size=256,
                       epochs=4,
                       callbacks=[keras.callbacks.EarlyStopping(),
                                  keras.callbacks.ModelCheckpoint("kaggle/working/baseline_checkpoints/cnn.keras",save_best_only=True)])

baseline_cnn_model.save("kaggle/working/baseline_cnn.keras")
# Out:
# Epoch 1/4
# 6189/6189 ━━━━━━━━━━━━━━━━━━━━ 2639s 426ms/step - accuracy: 0.7959 - auc: 0.8627 - loss: 0.4501 - val_accuracy: 0.7945 - val_auc: 0.9063 - val_loss: 0.4309
# Epoch 2/4
# 6189/6189 ━━━━━━━━━━━━━━━━━━━━ 2421s 391ms/step - accuracy: 0.8285 - auc: 0.9021 - loss: 0.3882 - val_accuracy: 0.8506 - val_auc: 0.9230 - val_loss: 0.3556
# Epoch 3/4
# 6189/6189 ━━━━━━━━━━━━━━━━━━━━ 2444s 394ms/step - accuracy: 0.8404 - auc: 0.9144 - loss: 0.3639 - val_accuracy: 0.8578 - val_auc: 0.9296 - val_loss: 0.3445
# Epoch 4/4
#  190/6189 ━━━━━━━━━━━━━━━━━━━━ 38:08 381ms/step - accuracy: 0.8553 - auc: 0.9218 - loss: 0.3490

# %% [markdown]
# ## Finetuning pretrained ConvNets
# ### ResNET50V2

# %%
#distributed training strategy
strategy = tf.distribute.MirroredStrategy()


    
with strategy.scope():
    
    
    
    resnet50v2_base = tf.keras.applications.ResNet50V2(include_top=False,
                                                    weights="imagenet",
                                                   input_shape=(224, 224, 3))
    
    for l in resnet50v2_base.layers[:-20]:
        l.trainable = False

    
    resnet50v2_model = keras.models.Sequential([
        tf.keras.layers.Input((224, 224, 3)),
        resnet50v2_base,
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    resnet50v2_model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.004),
                               loss="binary_crossentropy",
                               metrics=["accuracy", keras.metrics.AUC()])

    resnet50v2_model.summary()
    
    resnet50v2_train_history = resnet50v2_model.fit(train_generator,
                       validation_data=dev_generator,
                       batch_size=128,
                       epochs=4,
                       callbacks=[keras.callbacks.EarlyStopping(),
                                  keras.callbacks.ModelCheckpoint("kaggle/working/resnet50v2_checkpoints/resnet50v2.keras",save_best_only=True),
                                  keras.callbacks.BackupAndRestore(backup_dir="resnet50v2_backup/"),])
# Out:
# ...
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50v2 (Functional)         │ (None, 7, 7, 2048)     │    23,564,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# ...

# %%
resnet50v2_model.save("resnet50v2_trained09483.keras")

# %% [markdown]
# ### EfficientNet

# %%
#distributed training strategy
strategy = tf.distribute.MirroredStrategy()


    
with strategy.scope():
    
    
    
    effnet_base = tf.keras.applications.EfficientNetB1(include_top=False,
                                                    weights="imagenet",
                                                   input_shape=(224, 224, 3))
    #Gonna train all layers
    
    effnet_model = keras.models.Sequential([
        tf.keras.layers.Input((224, 224, 3)),
        effnet_base,
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    effnet_model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.004),
                               loss="binary_crossentropy",
                               metrics=["accuracy", keras.metrics.AUC()])

    effnet_model.summary()
    
    effnet_train_history = effnet_model.fit(train_generator,
                       validation_data=dev_generator,
                       batch_size=128,
                       epochs=8,
                       callbacks=[keras.callbacks.EarlyStopping(verbose=1),
                                  keras.callbacks.ModelCheckpoint("kaggle/working/effnet_checkpoints/effnet.keras",save_best_only=True),
                                  keras.callbacks.BackupAndRestore(backup_dir="effnet_backup/"),])
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb1 (Functional)     │ (None, 7, 7, 1280)     │     6,575,239 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
# ...

# %%
# Out:
# kaggle	resnet50v2_trained.keras  resnet50v2_trained09483.keras  state.db
